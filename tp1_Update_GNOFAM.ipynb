# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.ion()#mode interactif facilite l'utilisation de plusieurs figures

# %%
#fixer la graine aleatoire de numpy pour obtenir les mêmes resultats
np.random.seed(150)

# %%
#Definir la matrice de rotation et de dilatation
rot = np.array([[0.94,-0.34],[0.34,0.94]])
sca = np.array([[3.4, 0], [0, 2]])

# %%
# générer données classe 1
c1d = (np.random.randn(100,2)).dot(sca).dot(rot)

# %%
# générer données classe 2
c2d1 = np.random.randn(25,2)+[-10, 2]
c2d2 = np.random.randn(25,2)+[-7, -2]
c2d3 = np.random.randn(25,2)+[-2, -6]
c2d4 = np.random.randn(25,2)+[5, -7]

# %%
data = np.concatenate((c1d, c2d1, c2d2, c2d3, c2d4))

# %%
# générer étiquettes de classe 
l1c= np.ones(100, dtype=int) 
l2c =np.zeros(100, dtype=int) 
labels =np.concatenate((l1c, l2c))

# %%
#visualisatin des donnees
# les échantillons du premier groupe sont en rouge 'r', ceux du deuxième groupe envert (*green*) 'g'
cmp = np.array(['r','g'])
plt.figure()
plt.scatter(data[:,0],data[:,1], c=cmp[labels], s=50, edgecolors='none')

# %%
from sklearn.model_selection import train_test_split
plt.figure()
X_train1,X_test1,y_train1,y_test1=train_test_split(data,labels,test_size=0.33)
plt.scatter(X_train1[:,0],X_train1[:,1],c=cmp[y_train1],s=50,edgecolors='none')
plt.scatter(X_test1[:,0],X_test1[:,1],c='none',s=50,edgecolors=cmp[y_test1])

# %%
#nombre d'echantillons du jeu dapprentissage
print(X_train1.shape[0])
# Out:
# 134

# %%
#Exercice N°2

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis()

# %%
# évaluation et affichage sur split1
lda.fit(X_train1, y_train1)
# Out:
# LinearDiscriminantAnalysis()

# %%
print("Le score du jeu d'apprentissage est de / {}".format(lda.score(X_test1,y_test1)))
# Out:
# Le score du jeu d'apprentissage est de / 0.9393939393939394

# %%
# on créé une nouvelle figure sur laquelle on affiche les points
plt.figure()
plt.scatter(X_train1[:,0], X_train1[:,1], c=cmp[y_train1], s=50, edgecolors='none')
plt.scatter(X_test1[:,0],X_test1[:,1],c='none',s=50,edgecolors=cmp[y_test1])

# %%
plt.figure()
plt.scatter(X_train1[:,0], X_train1[:,1], c=cmp[y_train1], s=50, edgecolors='none')
plt.scatter(X_test1[:,0],X_test1[:,1],c='none',s=50,edgecolors=cmp[y_test1])
# on calcule pour chaque point du plan sa probabilité d'appartenir à chaque classe 
nx, ny = 200, 100
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, nx),np.linspace(y_min, y_max, ny))
Z = lda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z = Z[:, 1].reshape(xx.shape)
# on dessine la frontière correspond à une probabilité de 0,5
plt.contour(xx, yy, Z, [0.5])

# %%
#Generez d'autres decoupages apprentissage/test

# %%
#Decoupage 2
# générer données classe 2
c1d2 = (np.random.randn(100,2)).dot(sca).dot(rot)

# %%
# générer données classe 3
c2d12 = np.random.randn(25,2)+[-8, 2]
c2d22= np.random.randn(25,2)+[-10, -2]
c2d32 = np.random.randn(25,2)+[-6, -2]
c2d42 = np.random.randn(25,2)+[5, -7]

# %%
data2 = np.concatenate((c1d2, c2d12, c2d22, c2d32, c2d42))

# %%
# générer étiquettes de classe 
l1c2= np.ones(100, dtype=int) 
l2c2 =np.zeros(100, dtype=int) 
labels2 =np.concatenate((l1c2, l2c2))

# %%
#visualisatin des donnees
# les échantillons du premier groupe sont en rouge 'r', ceux du deuxième groupe envert (*green*) 'g'
cmp = np.array(['r','g'])
plt.figure()
plt.scatter(data2[:,0],data2[:,1], c=cmp[labels2], s=50, edgecolors='none')

# %%
from sklearn.model_selection import train_test_split
plt.figure()
X_train2,X_test2,y_train2,y_test2=train_test_split(data2,labels2,test_size=0.33)
plt.scatter(X_train2[:,0],X_train2[:,1],c=cmp[y_train2],s=50,edgecolors='none')
plt.scatter(X_test2[:,0],X_test2[:,1],c='none',s=50,edgecolors=cmp[y_test2])

# %%
# évaluation et affichage sur split1
lda.fit(X_train2, y_train2)
# Out:
# LinearDiscriminantAnalysis()

# %%
print("Le score du jeu d'apprentissage est de / {}".format(lda.score(X_test2,y_test2)))
# Out:
# Le score du jeu d'apprentissage est de / 0.8787878787878788

# %%
# on créé une nouvelle figure sur laquelle on affiche les points
plt.figure()
plt.scatter(X_train2[:,0], X_train2[:,1], c=cmp[y_train2], s=50, edgecolors='none')
plt.scatter(X_test2[:,0],X_test2[:,1],c='none',s=50,edgecolors=cmp[y_test2])

# %%
plt.figure()
plt.scatter(X_train2[:,0], X_train2[:,1], c=cmp[y_train2], s=50, edgecolors='none')
plt.scatter(X_test2[:,0],X_test2[:,1],c='none',s=50,edgecolors=cmp[y_test1])
# on calcule pour chaque point du plan sa probabilité d'appartenir à chaque classe 
nx, ny = 200, 100
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, nx),np.linspace(y_min, y_max, ny))
Z = lda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z = Z[:, 1].reshape(xx.shape)
# on dessine la frontière correspond à une probabilité de 0,5
plt.contour(xx, yy, Z, [0.5])

# %%
#Decoupage 3
# générer données classe 3
c1d3 = (np.random.randn(100,2)).dot(sca).dot(rot)

# %%
# générer données classe 4
c2d13 = np.random.randn(25,2)+[-6, 6]
c2d23= np.random.randn(25,2)+[-2, -10]
c2d33 = np.random.randn(25,2)+[-6, -6]
c2d43 = np.random.randn(25,2)+[-5, -7]

# %%
data3 = np.concatenate((c1d2, c2d12, c2d22, c2d32, c2d42))

# %%
# générer étiquettes de classe 
l1c3= np.ones(100, dtype=int) 
l2c3 =np.zeros(100, dtype=int) 
labels3 =np.concatenate((l1c3, l2c3))

# %%
#visualisatin des donnees
# les échantillons du premier groupe sont en rouge 'r', ceux du deuxième groupe envert (*green*) 'g'
cmp = np.array(['r','g'])
plt.figure()
plt.scatter(data3[:,0],data3[:,1], c=cmp[labels3], s=50, edgecolors='none')

# %%
from sklearn.model_selection import train_test_split
plt.figure()
X_train3,X_test3,y_train3,y_test3=train_test_split(data3,labels3,test_size=0.2)
plt.scatter(X_train3[:,0],X_train3[:,1],c=cmp[y_train3],s=50,edgecolors='none')
plt.scatter(X_test3[:,0],X_test3[:,1],c='none',s=50,edgecolors=cmp[y_test3])

# %%
# évaluation et affichage sur split1
lda.fit(X_train3, y_train3)
print("Le score du jeu d'apprentissage est de / {}".format(lda.score(X_test3,y_test3)))
# Out:
# Le score du jeu d'apprentissage est de / 0.825

# %%
# on créé une nouvelle figure sur laquelle on affiche les points
plt.figure()
plt.scatter(X_train3[:,0], X_train3[:,1], c=cmp[y_train3], s=50, edgecolors='none')
plt.scatter(X_test3[:,0],X_test3[:,1],c='none',s=50,edgecolors=cmp[y_test3])

# %%
plt.figure()
plt.scatter(X_train3[:,0], X_train3[:,1], c=cmp[y_train3], s=50, edgecolors='none')
plt.scatter(X_test3[:,0],X_test3[:,1],c='none',s=50,edgecolors=cmp[y_test3])
# on calcule pour chaque point du plan sa probabilité d'appartenir à chaque classe 
nx, ny = 200, 100
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, nx),np.linspace(y_min, y_max, ny))
Z = lda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z = Z[:, 1].reshape(xx.shape)
# on dessine la frontière correspond à une probabilité de 0,5
plt.contour(xx, yy, Z, [0.5])

# %%
#Exercice N°3

# %%
from sklearn.neural_network import MLPClassifier
# nous utilisons ici l'algorithme L-BFGS pour optimiser le perceptron 
clf = MLPClassifier(solver='lbfgs', alpha=1e-5)
# évaluation et affichage sur split1
clf.fit(X_train1, y_train1)
# Out:
# MLPClassifier(alpha=1e-05, solver='lbfgs')

# %%
train_score = clf.score(X_train1, y_train1)
print("Le score en train est {}".format(train_score))
test_score = clf.score(X_test1, y_test1)
print("Le score en test est {}".format(test_score))
# Out:
# Le score en train est 1.0
# Le score en test est 0.9242424242424242

# %%
# créer une nouvelle figure 
plt.figure()
# afficher les nuages de points apprentissage (remplis) et de test (vides)
plt.scatter(X_train1[:,0],X_train1[:,1],c=cmp[y_train1],s=50,edgecolors='none')
plt.scatter(X_test1[:,0],X_test1[:,1],c='none',s=50,edgecolors=cmp[y_test1])

# %%
# calculer la probabilité de sortie du perceptron pour tous les points duplan
nx= 200
ny = 200
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, nx),np.linspace(y_min,y_max, ny))
Z = clf.predict_proba(np.c_[xx.ravel(),yy.ravel()]) 
Z = Z[:,1].reshape(xx.shape)
# dessiner le contour correspondant à la frontière proba = 0,5
plt.contour(xx, yy, Z, [0.5])
# Out:
# /tmp/ipykernel_96140/1525634254.py:10: UserWarning: No contour levels were found within the data range.
#   plt.contour(xx, yy, Z, [0.5])

# %%
plt.figure()
# afficher les nuages de points apprentissage (remplis) et de test (vides)
plt.scatter(X_train1[:,0],X_train1[:,1],c=cmp[y_train1],s=50,edgecolors='none')
plt.scatter(X_test1[:,0],X_test1[:,1],c='none',s=50,edgecolors=cmp[y_test1]
)
# calculer la probabilité de sortie du perceptron pour tous les points duplan
nx, ny = 200, 200
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, nx),np.linspace(y_min,
y_max, ny))
Z = clf.predict_proba(np.c_[xx.ravel(),
yy.ravel()]) 
Z = Z[:, 1].reshape(xx.shape)
# dessiner le contour correspondant à la frontière proba = 0,5
plt.contour(xx, yy, Z, [0.5])

# %%
#ALPHA = 1

# %%
from sklearn.neural_network import MLPClassifier
# nous utilisons ici l'algorithme L-BFGS pour optimiser le perceptron 
clf1 = MLPClassifier(solver='lbfgs', alpha=1)
# évaluation et affichage sur split1
clf1.fit(X_train1, y_train1)
# Out:
# /home/etudiant/anaconda3/envs/envemmanuel/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# MLPClassifier(alpha=1, solver='lbfgs')

# %%
train_score1 = clf1.score(X_train1, y_train1)
print("Le score en train est {}".format(train_score1))
test_score1 = clf1.score(X_test1, y_test1)
print("Le score en test est {}".format(test_score1))
# Out:
# Le score en train est 0.9626865671641791
# Le score en test est 0.9393939393939394

# %%
# créer une nouvelle figure 
plt.figure()
# afficher les nuages de points apprentissage (remplis) et de test (vides)
plt.scatter(X_train1[:,0],X_train1[:,1],c=cmp[y_train1],s=50,edgecolors='none')
plt.scatter(X_test1[:,0],X_test1[:,1],c='none',s=50,edgecolors=cmp[y_test1])

# %%
plt.figure()
# afficher les nuages de points apprentissage (remplis) et de test (vides)
plt.scatter(X_train1[:,0],X_train1[:,1],c=cmp[y_train1],s=50,edgecolors='none')
plt.scatter(X_test1[:,0],X_test1[:,1],c='none',s=50,edgecolors=cmp[y_test1]
)
# calculer la probabilité de sortie du perceptron pour tous les points duplan
nx, ny = 200, 200
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, nx),np.linspace(y_min,
y_max, ny))
Z = clf.predict_proba(np.c_[xx.ravel(),
yy.ravel()]) 
Z = Z[:, 1].reshape(xx.shape)
# dessiner le contour correspondant à la frontière proba = 0,5
plt.contour(xx, yy, Z, [0.5])

# %%
#COMMENTAIRES
#PROBLEME DE CONVERGENCE

# %%
#La variabilité des résultats.

# %%
#Decoupage 2

# %%
clf.fit(X_train2, y_train2)
# Out:
# /home/etudiant/anaconda3/envs/envemmanuel/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# MLPClassifier(alpha=1e-05, solver='lbfgs')

# %%
train_score2 = clf.score(X_train2, y_train2)
print("Le score en train est {}".format(train_score2))
test_score2 = clf.score(X_test2, y_test2)
print("Le score en test est {}".format(test_score2))
# Out:
# Le score en train est 0.9776119402985075
# Le score en test est 0.9393939393939394

# %%
# créer une nouvelle figure 
plt.figure()
# afficher les nuages de points apprentissage (remplis) et de test (vides)
plt.scatter(X_train2[:,0],X_train2[:,1],c=cmp[y_train2],s=50,edgecolors='none')
plt.scatter(X_test2[:,0],X_test2[:,1],c='none',s=50,edgecolors=cmp[y_test2])

# %%
plt.figure()
# afficher les nuages de points apprentissage (remplis) et de test (vides)
plt.scatter(X_train2[:,0],X_train2[:,1],c=cmp[y_train2],s=50,edgecolors='none')
plt.scatter(X_test2[:,0],X_test2[:,1],c='none',s=50,edgecolors=cmp[y_test2]
)
# calculer la probabilité de sortie du perceptron pour tous les points duplan
nx, ny = 200, 200
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, nx),np.linspace(y_min,
y_max, ny))
Z = clf.predict_proba(np.c_[xx.ravel(),
yy.ravel()]) 
Z = Z[:, 1].reshape(xx.shape)
# dessiner le contour correspondant à la frontière proba = 0,5
plt.contour(xx, yy, Z, [0.5])

# %%
#Decoupage 3

# %%
clf.fit(X_train3, y_train3)
# Out:
# MLPClassifier(alpha=1e-05, solver='lbfgs')

# %%
train_score3 = clf.score(X_train3, y_train3)
print("Le score en train est {}".format(train_score3))
test_score3 = clf.score(X_test3, y_test3)
print("Le score en test est {}".format(test_score3))
# Out:
# Le score en train est 0.99375
# Le score en test est 0.95

# %%
# créer une nouvelle figure 
plt.figure()
# afficher les nuages de points apprentissage (remplis) et de test (vides)
plt.scatter(X_train3[:,0],X_train3[:,1],c=cmp[y_train3],s=50,edgecolors='none')
plt.scatter(X_test3[:,0],X_test3[:,1],c='none',s=50,edgecolors=cmp[y_test3])

# %%
plt.figure()
# afficher les nuages de points apprentissage (remplis) et de test (vides)
plt.scatter(X_train3[:,0],X_train3[:,1],c=cmp[y_train3],s=50,edgecolors='none')
plt.scatter(X_test3[:,0],X_test3[:,1],c='none',s=50,edgecolors=cmp[y_test3]
)
# calculer la probabilité de sortie du perceptron pour tous les points duplan
nx, ny = 200, 200
x_min, x_max = plt.xlim()
y_min, y_max = plt.ylim()
xx, yy = np.meshgrid(np.linspace(x_min, x_max, nx),np.linspace(y_min,
y_max, ny))
Z = clf.predict_proba(np.c_[xx.ravel(),
yy.ravel()]) 
Z = Z[:, 1].reshape(xx.shape)
# dessiner le contour correspondant à la frontière proba = 0,5
plt.contour(xx, yy, Z, [0.5])

# %%
#Exercice N° 4

# %%
# définir matrices de rotation et de dilatation
rot = np.array([[0.94, 0.34], [-0.34, 0.94]]) 
sca = np.array([[10, 0], [0, 1]])

# %%
# générer données bidimensionnelles
np.random.seed(60)
rd = np.random.randn(60,2)
datar = rd.dot(sca).dot(rot)

# %%
#Visualisation de toutes les données :
plt.figure()
plt.scatter(datar[:,0],datar[:,1],s=50,edgecolors='none')

# %%
from sklearn.model_selection import train_test_split
plt.figure()
X_train1, X_test1,y_train1,y_test1=train_test_split(datar[:,0],datar[:,1], test_size=0.33)
plt.scatter(X_train1,y_train1,s=50,edgecolors='none')
plt.scatter(X_test1,y_test1,c='none',s=50,edgecolors='blue')

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
# évaluation et affichage sur split1
reg.fit(X_train1.reshape(-1,1), y_train1)
# attention, score() ici ne renvoie pas l'erreur mais la valeur du coefficient de détermination R² !
coeff_train = reg.score(X_train1.reshape(-1,1), y_train1)
print("Coefficient de détermination R² en train : {}".format(coeff_train))
coeff_test = reg.score(X_test1.reshape(-1,1), y_test1)
print("Coefficient de détermination R² en test : {}".format(coeff_train))
# Out:
# Coefficient de détermination R² en train : 0.9050503868590944
# Coefficient de détermination R² en test : 0.9050503868590944

# %%
plt.figure()
plt.scatter(X_train1,y_train1,s=50,edgecolors='none')
plt.scatter(X_test1,y_test1,c='none',s=50,edgecolors='blue')
nx = 100
x_min, x_max = plt.xlim()
xx = np.linspace(x_min, x_max, nx)
plt.plot(xx,reg.predict(xx.reshape(-1,1)),color='black')

# %%
from sklearn.neural_network import MLPRegressor
clf = MLPRegressor(solver='lbfgs', alpha=1e-5)
# évaluation et affichage sur split1
clf.fit(X_train1.reshape(-1,1), y_train1)
coeff_train = clf.score(X_train1.reshape(-1,1), y_train1)
print("Le coefficient R² de train est {}".format(coeff_train))
coeff_test = clf.score(X_test1.reshape(-1,1), y_test1)
print("Le coefficient R² de test est {}".format(coeff_train))
# Out:
# Le coefficient R² de train est 0.9158151118850026
# Le coefficient R² de test est 0.9158151118850026
# /home/etudiant/anaconda3/envs/envemmanuel/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
plt.figure()
plt.scatter(X_train1,y_train1,s=50,edgecolors='none')
plt.scatter(X_test1,y_test1,c='none',s=50,edgecolors='blue')
nx = 100
x_min, x_max = plt.xlim()
xx = np.linspace(x_min, x_max, nx)
plt.plot(xx,reg.predict(xx.reshape(-1,1)),color='black')

# %%
#Calculez l’erreur quadratique moyenne du modèle sur les données d’apprentissage et ensuite sur les données de test.

# %%
#Générez de nouvelles données avec cette nouvelle matrice de dilation. Quel est l’impact de
#cette augmentation de la variance sur le coefficient de détermination obtenu sur les données de
#test ? Essayez avec les valeurs 2, 4 et 6 pour et2. Vous pouvez faire une représentation
#graphique de l’évolution de la valeur obtenue pour reg.score(X_test1.reshape(-1,1), y_test1)
#lorsque et2 augmente.

# %%
#Générez de nouvelles données avec cette nouvelle matrice de dilation. Quel est l’impact de
#cette augmentation de la variance sur le coefficient de détermination obtenu sur les données de
#test ? Essayez avec les valeurs 2, 4 et 6 pour et2. Vous pouvez faire une représentation
#graphique de l’évolution de la valeur obtenue pour reg.score(X_test1.reshape(-1,1), y_test1)
#lorsque et2 augmente.

# %%
#Générez de nouvelles données avec cette nouvelle matrice de dilation. Quel est l’impact de
#cette augmentation de la variance sur le coefficient de détermination obtenu sur les données de
#test ? Essayez avec les valeurs 2, 4 et 6 pour et2. Vous pouvez faire une représentation
#graphique de l’évolution de la valeur obtenue pour reg.score(X_test1.reshape(-1,1), y_test1)
#lorsque et2 augmente.

# %%
#Générez de nouvelles données avec cette nouvelle matrice de dilation. Quel est l’impact de
#cette augmentation de la variance sur le coefficient de détermination obtenu sur les données de
#test ? Essayez avec les valeurs 2, 4 et 6 pour et2. Vous pouvez faire une représentation
#graphique de l’évolution de la valeur obtenue pour reg.score(X_test1.reshape(-1,1), y_test1)
#lorsque et2 augmente.

# %%
#Générez de nouvelles données avec cette nouvelle matrice de dilation. Quel est l’impact de
#cette augmentation de la variance sur le coefficient de détermination obtenu sur les données de
#test ? Essayez avec les valeurs 2, 4 et 6 pour et2. Vous pouvez faire une représentation
#graphique de l’évolution de la valeur obtenue pour reg.score(X_test1.reshape(-1,1), y_test1)
#lorsque et2 augmente.

# %%
#PMC pour faire la régression

# %%
from sklearn.neural_network import MLPRegressor
clf = MLPRegressor(solver='lbfgs', alpha=1e-5)
# évaluation et affichage sur split1
clf.fit(X_train1.reshape(-1,1), y_train1)
coeff_train = clf.score(X_train1.reshape(-1,1), y_train1)
print("Le coefficient R² de train est {}".format(coeff_train))
coeff_test = clf.score(X_test1.reshape(-1,1), y_test1)
print("Le coefficient R² de test est {}".format(coeff_train))
# Out:
# Le coefficient R² de train est 0.915696783202722
# Le coefficient R² de test est 0.915696783202722
# /home/etudiant/anaconda3/envs/envemmanuel/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
plt.figure()
plt.scatter(X_train1,y_train1,s=50,edgecolors='none')
plt.scatter(X_test1,y_test1,c='none',s=50,edgecolors='blue')
x_min, x_max = plt.xlim()
xx = np.linspace(x_min, x_max, nx)
plt.plot(xx,clf.predict(xx.reshape(-1,1)),color='black')

# %%
#Refaites l’expérience avec alpha = 1. Quelle est la conséquence sur les résultats ?
